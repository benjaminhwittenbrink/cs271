# %%
import pandas as pd

# %%
## NOTE: FILL THESE IN: 
country_codes = ['AL']
# main project directory 
PROJECT_FOLDER = "drive/MyDrive"
# where data folders are stored (probably full_dataset_tfrecord)
in_folder = PROJECT_FOLDER + "/" + "bmi"
# where dat folders should be  written 
out_folder = PROJECT_FOLDER + "/" + "bmi/OUT_FOLDER/" 
# make sure path is correct
df = pd.read_csv("drive/MyDrive/bmi/hi.csv")

# %%
import pandas as pd
WA_df = pd.read_csv("drive/MyDrive/bmi/west_africa_df.csv")

# %%
WA_df.loc[WA_df['Under5_Mortality_Rate'] > 35]
# Out:
#       Unnamed: 0           DHSID  DHSYEAR  DHSCLUST     LATNUM    LONGNUM  \
# 128          128  BF201000000129   2010.0     129.0  13.783894  -0.132581
# 323          323  BF201000000324   2010.0     324.0  13.677286  -0.039002
# 349          349  BF201000000350   2010.0     350.0  13.208367  -3.965377
# 547          547  BF201000000549   2010.0     549.0  14.033615   0.089241
# 1375        1375  CF199400000216   1994.0     216.0   5.800000  14.816700
# 1480        1480  CF199400000508   1994.0     508.0   5.400000  26.500000
# 1769        1769  CI201200000216   2012.0     216.0   8.273471  -8.166579
# 2176        2176  CM201100000272   2011.0     272.0  11.242376  14.141619
# 3846        3846  ML201200000279   2012.0     279.0  14.242414  -3.881372
# 4439        4439  NG201800000380   2018.0     380.0  10.545622  11.321537
# 4509        4509  NG201800000450   2018.0     450.0  12.972527   9.939095
# 4541        4541  NG201800000482   2018.0     482.0  12.552448   9.643095
# 4719        4719  NG201800000663   2018.0     663.0  12.092070   4.129636
# 5486        5486  SL201900000038   2019.0      38.0   7.742512 -11.836157
# 5533        5533  SL201900000085   2019.0      85.0   0.000000   0.000000
# 5720        5720  SL201900000273   2019.0     273.0   8.507326 -12.591535
# 5759        5759  SL201900000312   2019.0     312.0   7.937216 -11.944612
# 5843        5843  SL201900000397   2019.0     397.0   7.343938 -11.597206
# 6605        6605  TD201400000190   2014.0     190.0   8.582394  17.318881
#
#       Mean_BMI  Median_BMI  Unmet_Need_Rate  Under5_Mortality_Rate  \
# 128      23.34       23.34            45.45                  37.98
# 323      20.31       19.41           100.00                  36.26
# 349      22.43       22.43           100.00                  35.92
# 547      22.98       22.98            25.00                  46.02
# 1375       NaN         NaN            50.00                  42.86
# 1480       NaN         NaN              NaN                  36.36
# 1769     21.95       21.95            60.00                  36.59
# 2176     22.85       21.24            85.71                  36.05
# 3846     19.57       19.36            85.71                  35.34
# 4439     20.77       20.12            76.92                  35.46
# 4509     19.63       18.81           100.00                  37.36
# 4541     18.43       18.18           100.00                  36.31
# 4719     21.62       21.50           100.00                  36.99
# 5486     20.70       20.34            28.57                  43.86
# 5533       NaN         NaN              NaN                  50.00
# 5720     21.04       19.93            60.00                  36.36
# 5759     22.73       22.94            41.67                  43.12
# 5843     19.85       19.64             0.00                  40.00
# 6605     28.14       28.14            66.67                  37.76
#
#       Skilled_Birth_Attendant_Rate  Stunted_Rate  \
# 128                           3.12         46.15
# 323                           0.00         20.00
# 349                           8.00         40.00
# 547                           0.00         42.86
# 1375                          0.00           NaN
# 1480                        100.00           NaN
# 1769                         10.81         23.81
# 2176                         28.95         33.33
# 3846                          0.00         42.86
# 4439                         32.20         64.71
# 4509                          8.82         66.67
# 4541                         40.00         77.78
# 4719                          2.00         77.78
# 5486                         86.36         27.27
# 5533                           NaN          0.00
# 5720                         60.00          0.00
# 5759                         52.17         50.00
# 5843                        100.00        100.00
# 6605                         13.79         16.67
#
#       Fully_Vaccinated_Children_Rate URBAN_RURA country  year  Mean_BMI_bin  \
# 128                              NaN          R      BF  2010             1
# 323                              NaN          R      BF  2010             1
# 349                              NaN          R      BF  2010             1
# 547                              NaN          R      BF  2010             1
# 1375                             NaN          U      CF  1994             2
# 1480                             NaN          U      CF  1994             2
# 1769                             NaN          R      CI  2012             1
# 2176                             NaN          R      CM  2011             1
# 3846                             NaN          R      ML  2012             0
# 4439                            3.23          R      NG  2018             1
# 4509                            0.00          R      NG  2018             0
# 4541                           13.64          R      NG  2018             0
# 4719                            0.00          R      NG  2018             1
# 5486                           69.23          R      SL  2019             1
# 5533                             NaN          R      SL  2019             2
# 5720                           20.00          R      SL  2019             1
# 5759                            0.00          R      SL  2019             1
# 5843                          100.00          R      SL  2019             0
# 6605                             NaN          R      TD  2014             2
#
#       Under5_Mortality_Rate_bin  Under5_Mortality_Rate_bin_quint  \
# 128                           2                                4
# 323                           2                                4
# 349                           2                                4
# 547                           2                                4
# 1375                          2                                4
# 1480                          2                                4
# 1769                          2                                4
# 2176                          2                                4
# 3846                          2                                4
# 4439                          2                                4
# 4509                          2                                4
# 4541                          2                                4
# 4719                          2                                4
# 5486                          2                                4
# 5533                          2                                4
# 5720                          2                                4
# 5759                          2                                4
# 5843                          2                                4
# 6605                          2                                4
#
#       Mean_BMI_bin_quint
# 128                    3
# 323                    0
# 349                    2
# 547                    2
# 1375                   0
# 1480                   0
# 1769                   1
# 2176                   2
# 3846                   0
# 4439                   0
# 4509                   0
# 4541                   0
# 4719                   1
# 5486                   0
# 5533                   0
# 5720                   1
# 5759                   2
# 5843                   0
# 6605                   4

# %%
print(WA_df['Under5_Mortality_Rate'].min())
print(WA_df['Under5_Mortality_Rate'].max())
# Out:
# 0.0
# 50.0

# %%
df = df.loc[df["DHSID"].str[0:2].isin(country_codes)]

# %%
# pick the year with most images for each country
df_cntry_yr = df.groupby(["DHSYEAR"])["DHSID"].count()
df_cntry_yr.sort_values(ascending=False)
df_cntry_yr
#df = df.merge(df_cntry_yr[["DHSYEAR"]], on = ["DHSYEAR"], how = "inner")
# Out:
# DHSYEAR
# 2008.0    450
# 2017.0    715
# Name: DHSID, dtype: int64

# %%
df_cntry_yr.idxmax()
# Out:
# 2017.0

# %%
df = df.iloc[np.where(df['DHSYEAR'] == df_cntry_yr.idxmax())]

# %%
import numpy as np

# %%
df["Infant_Mortality_Bin"] = np.select(
        [df["Under5_Mortality_Rate"] <= 16.6, df["Mean_BMI"] <= 33.2, True], 
        [0, 1, 2]
    )
mort_N_CLASSES = df["Infant_Mortality_Bin"].drop_duplicates().shape[0]
mort_dhsid_label_dict = dict(zip(df["DHSID"], df["Infant_Mortality_Bin"]))

# %%
df["Infant_Mortality_Bin"].value_counts()
# Out:
# 0    71259
# 1    38151
# 2     4702
# Name: Infant_Mortality_Bin, dtype: int64

# %%
pd.DataFrame.hist(df, 'Under5_Mortality_Rate', grid=False, bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f86b0d59a60>]],
#       dtype=object)

# %%
new_df = df[['URBAN_RURA', 'Under5_Mortality_Rate']]
R = new_df.loc[np.where(new_df['URBAN_RURA'] == 'R')]
U = new_df.loc[np.where(new_df['URBAN_RURA'] == 'U')]
plt.hist([R['Under5_Mortality_Rate'], U['Under5_Mortality_Rate']], range=(0, 40), alpha=0.5, label=['Rural', 'Urban'], color=['red', 'blue'])
#plt.hist(U['Under5_Mortality_Rate'], alpha=0.5, label='Urban', color='blue')
plt.legend(loc='upper right')
plt.xlabel('Mortality Rate')
plt.ylabel('Count')
plt.title('Infant Mortality Rate Across Different Environments')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
import seaborn as sns
sns.set(style="ticks", color_codes=True)    
new_df = df[['Fully_Vaccinated_Children_Rate', 'Under5_Mortality_Rate']][:10000]
new_df = new_df.loc[(new_df != 0).all(axis=1)]
g = sns.pairplot(new_df, height=5)
plt.show()

# %%
df[['LATNUM', 'LONGNUM', 'DHSID']].to_csv('latlong.csv', index=False)

# %%
df[['LATNUM', 'LONGNUM', 'DHSID']].round(3).to_csv('latlong.csv', index=False)

# %%
import matplotlib.pyplot as plt
n, bins, patches = plt.hist(df['Under5_Mortality_Rate'], range=(0, 50), bins=30, edgecolor='#ffffff')
n = n.astype('int') # it MUST be integer
# Good old loop. Choose colormap of your taste
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
# Make one bin stand out   
plt.title('Infant Mortality Rate for Various Regions in Algeria')
plt.xlabel('Mortality Rate')
plt.ylabel('Count')
plt.show()
plt.savefig('infant_mortality_hist')

# %%
import os
os.mkdir(out_folder)
for i in range(N_CLASSES):
  os.mkdir(out_folder + "class_" + str(i))

# %%
# !ls
# Out:
# drive  sample_data

# %%
missing_dhsids = np.load('drive/MyDrive/bmi/missing_mosaiks_dhsids.npy', allow_pickle=True)

# %%
filtered_df = WA_df.loc[WA_df['DHSID'].isin(missing_dhsids)]
filtered_df.to_csv('missing_dhsids_df.csv')

# %%
new_filtered = filtered_df.sort_values(by=['LATNUM', 'LONGNUM'])

# %%
new_filtered
# Out:
#                DHSID  DHSYEAR  DHSCLUST     LATNUM    LONGNUM  Mean_BMI  \
# 2640  GA201200000158   2012.0     158.0  -3.434576  10.656524     25.20
# 2561  GA201200000079   2012.0      79.0  -3.205067  11.209355     21.29
# 2601  GA201200000119   2012.0     119.0  -3.066009  10.848087     23.30
# 2571  GA201200000089   2012.0      89.0  -2.826050  11.522820     21.72
# 2667  GA201200000185   2012.0     185.0  -2.645696  11.160438     21.27
# ...              ...      ...       ...        ...        ...       ...
# 6398  SN201000000375   2010.0     375.0  16.210195 -16.371688     28.50
# 6169  SN201000000146   2010.0     146.0  16.479906 -15.989064     21.14
# 6982  TD201400000569   2014.0     569.0  18.515294  18.988412     19.81
# 6691  TD201400000276   2014.0     276.0  20.727619  17.099408     24.27
# 6894  TD201400000480   2014.0     480.0  21.359241  16.989101     19.57
#
#       Median_BMI  Unmet_Need_Rate  Under5_Mortality_Rate  \
# 2640       24.05            29.41                   4.88
# 2561       21.29            57.14                   6.45
# 2601       23.30            60.00                   8.57
# 2571       21.01            35.29                   5.26
# 2667       22.10            62.50                   5.41
# ...          ...              ...                    ...
# 6398       28.50           100.00                   2.30
# 6169       19.04            52.38                   3.88
# 6982       19.65           100.00                   1.54
# 6691       24.87           100.00                   4.41
# 6894       18.77           100.00                  10.26
#
#       Skilled_Birth_Attendant_Rate  Stunted_Rate  \
# 2640                         75.00          0.00
# 2561                         15.00         44.44
# 2601                         77.78         44.44
# 2571                         54.17         25.00
# 2667                         31.25         35.71
# ...                            ...           ...
# 6398                         67.86         36.36
# 6169                         83.87          8.33
# 6982                          0.00         27.27
# 6691                          0.00         60.00
# 6894                         11.11         40.00
#
#       Fully_Vaccinated_Children_Rate URBAN_RURA country  year  Mean_BMI_bin  \
# 2640                             NaN          U      GA  2012             2
# 2561                             NaN          R      GA  2012             1
# 2601                             NaN          R      GA  2012             1
# 2571                             NaN          U      GA  2012             1
# 2667                             NaN          R      GA  2012             1
# ...                              ...        ...     ...   ...           ...
# 6398                             NaN          R      SN  2010             2
# 6169                             NaN          R      SN  2010             1
# 6982                             NaN          R      TD  2014             0
# 6691                             NaN          R      TD  2014             1
# 6894                             NaN          U      TD  2014             0
#
#       Under5_Mortality_Rate_bin
# 2640                          0
# 2561                          0
# 2601                          0
# 2571                          0
# 2667                          0
# ...                         ...
# 6398                          0
# 6169                          0
# 6982                          0
# 6691                          0
# 6894                          1
#
# [581 rows x 17 columns]

# %%
missing_mosaik = pd.read_csv('Mosaiks_features 5.csv')

# %%
final_df = new_filtered[['DHSID', 'Mean_BMI', 'Mean_BMI_bin']].reset_index(drop=True)
final_df
# Out:
#               DHSID  Mean_BMI  Mean_BMI_bin
# 0    GA201200000158     25.20             2
# 1    GA201200000079     21.29             1
# 2    GA201200000119     23.30             1
# 3    GA201200000089     21.72             1
# 4    GA201200000185     21.27             1
# ..              ...       ...           ...
# 576  SN201000000375     28.50             2
# 577  SN201000000146     21.14             1
# 578  TD201400000569     19.81             0
# 579  TD201400000276     24.27             1
# 580  TD201400000480     19.57             0
#
# [581 rows x 3 columns]

# %%
complete_df = pd.concat([newest.reset_index(drop=True), final_df], axis=1)
complete_df
# Out:
#         Lat     Lon                  .1        .2        .3        .4  \
# 0    -3.435  10.655  0.236969  0.737643  0.056487  0.465031  0.417166
# 1    -3.320  10.930  0.121248  0.374461  0.030598  0.232522  0.210519
# 2    -3.205  11.205  0.005527  0.011279  0.004709  0.000013  0.003871
# 3    -3.135  11.025  0.006615  0.017750  0.003823  0.000345  0.005298
# 4    -3.065  10.845  0.007703  0.024222  0.002936  0.000678  0.006726
# ..      ...     ...       ...       ...       ...       ...       ...
# 576  16.215 -16.375  0.271315  0.609338  0.088504  0.432711  0.421561
# 577  16.475 -15.985  0.100152  0.395019  0.002904  0.680612  0.216738
# 578  18.515  18.985  0.122368  0.482700  0.003882  0.831657  0.254973
# 579  20.725  17.095  0.144272  0.535970  0.007348  0.911490  0.289562
# 580  21.355  16.985  0.170205  0.631711  0.009856  0.903199  0.364245
#
#            .5        .6        .7  ...     .3993     .3994     .3995  \
# 0    0.645002  0.190591  0.170996  ...  0.368575  0.348760  1.373076
# 1    0.338704  0.112101  0.203338  ...  0.218436  0.177656  0.708352
# 2    0.032407  0.033610  0.235680  ...  0.068296  0.006553  0.043629
# 3    0.026709  0.028456  0.146366  ...  0.042151  0.003888  0.033472
# 4    0.021011  0.023302  0.057051  ...  0.016006  0.001222  0.023316
# ..        ...       ...       ...  ...       ...       ...       ...
# 576  0.444456  0.085234  0.132011  ...  0.258876  0.205311  0.927276
# 577  0.045163  0.013459  0.005421  ...  0.001143  0.000939  0.159556
# 578  0.111342  0.010960  0.008619  ...  0.009032  0.021862  0.367845
# 579  0.116808  0.016587  0.008054  ...  0.023291  0.049158  0.569641
# 580  0.212050  0.030203  0.025561  ...  0.082741  0.070002  0.745069
#
#         .3996     .3997     .3998     .3999           DHSID  Mean_BMI  \
# 0    2.388049  1.226486  0.936166  0.130382  GA201200000158     25.20
# 1    1.521233  0.637020  0.471264  0.080935  GA201200000079     21.29
# 2    0.654417  0.047554  0.006361  0.031489  GA201200000119     23.30
# 3    0.469190  0.042782  0.004748  0.016763  GA201200000089     21.72
# 4    0.283962  0.038010  0.003135  0.002037  GA201200000185     21.27
# ..        ...       ...       ...       ...             ...       ...
# 576  1.766822  0.376410  0.553351  0.035951  SN201000000375     28.50
# 577  0.119713  0.028424  0.100250  0.000010  SN201000000146     21.14
# 578  0.231125  0.074841  0.389985  0.000023  TD201400000569     19.81
# 579  0.416103  0.124362  0.531170  0.001448  TD201400000276     24.27
# 580  0.690587  0.259495  0.517575  0.009962  TD201400000480     19.57
#
#      Mean_BMI_bin
# 0               2
# 1               1
# 2               1
# 3               1
# 4               1
# ..            ...
# 576             2
# 577             1
# 578             0
# 579             1
# 580             0
#
# [581 rows x 4005 columns]

# %%
complete_df.to_csv('missing_mosaiks_feats.csv')

# %%
WA_df = WA_df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'], axis=1)

# %%
new_filtered = filtered_df.sort_values(by=['LATNUM', 'LONGNUM'])
# Out:
#                DHSID  DHSYEAR  DHSCLUST     LATNUM   LONGNUM  Mean_BMI  \
# 0     BF201000000001   2010.0       1.0  10.109415 -2.807555     19.37
# 1     BF201000000002   2010.0       2.0  10.388513 -3.907798     19.30
# 2     BF201000000003   2010.0       3.0   9.882864 -2.925703     21.20
# 3     BF201000000004   2010.0       4.0  13.573418 -2.163120     17.86
# 4     BF201000000005   2010.0       5.0  12.453299 -3.461899     21.06
# ...              ...      ...       ...        ...       ...       ...
# 7365  TG201300000326   2013.0     326.0   6.184043  1.277230     28.85
# 7366  TG201300000327   2013.0     327.0   6.190206  1.184532     25.12
# 7367  TG201300000328   2013.0     328.0   6.346956  1.470073     23.93
# 7368  TG201300000329   2013.0     329.0   6.166961  1.266781     24.86
# 7369  TG201300000330   2013.0     330.0   9.768948  1.324937     22.44
#
#       Median_BMI  Unmet_Need_Rate  Under5_Mortality_Rate  \
# 0          19.74            33.33                  18.97
# 1          18.93            58.33                  22.67
# 2          19.47            44.44                  31.40
# 3          17.72            71.43                  13.21
# 4          20.51            88.89                   7.84
# ...          ...              ...                    ...
# 7365       25.58            64.29                  13.24
# 7366       23.78            42.86                   8.57
# 7367       24.28            50.00                   9.68
# 7368       26.01            53.33                   1.92
# 7369       21.89            50.00                  11.86
#
#       Skilled_Birth_Attendant_Rate  Stunted_Rate  \
# 0                             0.00         20.00
# 1                            26.92         55.56
# 2                            22.73         50.00
# 3                            14.29         20.00
# 4                            12.00         35.71
# ...                            ...           ...
# 7365                         52.63         25.00
# 7366                        100.00          0.00
# 7367                         85.71         40.00
# 7368                         61.54          0.00
# 7369                          3.57         21.43
#
#       Fully_Vaccinated_Children_Rate URBAN_RURA country  year  Mean_BMI_bin  \
# 0                                NaN          R      BF  2010             0
# 1                                NaN          R      BF  2010             0
# 2                                NaN          U      BF  2010             1
# 3                                NaN          R      BF  2010             0
# 4                                NaN          R      BF  2010             1
# ...                              ...        ...     ...   ...           ...
# 7365                             NaN          U      TG  2013             2
# 7366                             NaN          U      TG  2013             2
# 7367                             NaN          R      TG  2013             1
# 7368                             NaN          U      TG  2013             1
# 7369                             NaN          R      TG  2013             1
#
#       Under5_Mortality_Rate_bin
# 0                             1
# 1                             2
# 2                             2
# 3                             1
# 4                             0
# ...                         ...
# 7365                          1
# 7366                          0
# 7367                          0
# 7368                          0
# 7369                          1
#
# [7370 rows x 17 columns]

# %%
WA_df[['LATNUM', 'LONGNUM']].to_csv('west_africa_latlong.csv')

# %%
len(mosaiks_features.columns)
# Out:
# 4002

# %%
df = WA_df

# %%
df.round(3)
# Out:
#       Unnamed: 0           DHSID  DHSYEAR  DHSCLUST  LATNUM  LONGNUM  \
# 450          450  AL201700000001   2017.0       1.0  40.710   19.947
# 451          451  AL201700000002   2017.0       2.0  40.707   19.929
# 452          452  AL201700000003   2017.0       3.0  40.700   19.941
# 453          453  AL201700000004   2017.0       4.0  40.707   19.935
# 454          454  AL201700000005   2017.0       5.0  40.711   19.946
# ...          ...             ...      ...       ...     ...      ...
# 1160        1160  AL201700000711   2017.0     711.0  40.463   19.552
# 1161        1161  AL201700000712   2017.0     712.0  40.501   19.543
# 1162        1162  AL201700000713   2017.0     713.0  40.564   19.536
# 1163        1163  AL201700000714   2017.0     714.0  40.251   19.659
# 1164        1164  AL201700000715   2017.0     715.0  40.474   19.682
#
#       Mean_BMI  Median_BMI  Unmet_Need_Rate  Under5_Mortality_Rate  \
# 450      26.22       24.87           100.00                    0.0
# 451      25.00       25.08            66.67                    0.0
# 452      25.30       25.19             0.00                    0.0
# 453      25.94       26.41            66.67                    0.0
# 454      26.43       24.95             0.00                    0.0
# ...        ...         ...              ...                    ...
# 1160     23.21       22.37             0.00                    0.0
# 1161     25.98       26.40            28.57                    0.0
# 1162     27.52       24.50           100.00                    0.0
# 1163     26.30       25.88             0.00                    0.0
# 1164     26.84       26.54           100.00                    0.0
#
#       Skilled_Birth_Attendant_Rate  Stunted_Rate  \
# 450                          85.71          0.00
# 451                          75.00          0.00
# 452                         100.00          0.00
# 453                         100.00          0.00
# 454                         100.00          0.00
# ...                            ...           ...
# 1160                          0.00          0.00
# 1161                         66.67          0.00
# 1162                        100.00         20.00
# 1163                         25.00         25.00
# 1164                         33.33         33.33
#
#       Fully_Vaccinated_Children_Rate URBAN_RURA
# 450                              0.0          U
# 451                              0.0          U
# 452                              0.0          U
# 453                              0.0          U
# 454                              0.0          U
# ...                              ...        ...
# 1160                             0.0          R
# 1161                             0.0          R
# 1162                             0.0          R
# 1163                             0.0          R
# 1164                             0.0          R
#
# [715 rows x 14 columns]

# %%
mosaiks_features = mosaiks_features.sort_values(by=['Lat', 'Lon'])

# %%
mosaiks_features
# Out:
#          Lat     Lon                  .1        .2        .3        .4  \
# 1583  -3.805  11.115  0.003567  0.009148  0.001063  0.000616  0.002156
# 1599  -3.795  11.175  0.048069  0.240347  0.011166  0.140129  0.097734
# 1487  -3.435  10.655  0.236969  0.737643  0.056487  0.465031  0.417166
# 1760  -3.325  11.715  0.021291  0.084021  0.005456  0.021787  0.041146
# 1492  -3.265  10.685  0.010693  0.023065  0.008814  0.001304  0.011100
# ...      ...     ...       ...       ...       ...       ...       ...
# 6192  20.725  17.095  0.144272  0.535970  0.007348  0.911490  0.289562
# 6245  21.005  18.065  0.085786  0.431654  0.004482  0.781966  0.194547
# 6214  21.205  17.465  0.110492  0.399591  0.017003  0.592871  0.219231
# 6184  21.355  16.985  0.170205  0.631711  0.009856  0.903199  0.364245
# 6212  21.825  17.445  0.121627  0.536978  0.003440  0.856000  0.255904
#
#             .5        .6        .7  ...     .3990     .3991     .3992  \
# 1583  0.019884  0.016484  0.048069  ...  0.000833  0.000678  0.028277
# 1599  0.193909  0.061233  0.079044  ...  0.045901  0.038110  0.206072
# 1487  0.645002  0.190591  0.170996  ...  0.547161  0.168255  0.529643
# 1760  0.068473  0.049016  0.050041  ...  0.031601  0.009235  0.063047
# 1492  0.051731  0.023326  0.178463  ...  0.016340  0.021286  0.179684
# ...        ...       ...       ...  ...       ...       ...       ...
# 6192  0.116808  0.016587  0.008054  ...  0.045996  0.011583  0.061987
# 6245  0.058194  0.012264  0.005279  ...  0.044903  0.008777  0.024613
# 6214  0.145222  0.017122  0.032927  ...  0.076904  0.014516  0.114672
# 6184  0.212050  0.030203  0.025561  ...  0.092151  0.008557  0.161044
# 6212  0.084938  0.010842  0.004230  ...  0.049305  0.000662  0.024323
#
#          .3993     .3994     .3995     .3996     .3997     .3998     .3999
# 1583  0.007653  0.000426  0.009639  0.186551  0.007131  0.005298  0.000561
# 1599  0.079954  0.073183  0.258299  0.717489  0.195653  0.185818  0.033173
# 1487  0.368575  0.348760  1.373076  2.388049  1.226486  0.936166  0.130382
# 1760  0.037590  0.024492  0.145613  0.360640  0.163581  0.063596  0.011379
# 1492  0.058314  0.009046  0.041749  0.603708  0.033940  0.016449  0.013595
# ...        ...       ...       ...       ...       ...       ...       ...
# 6192  0.023291  0.049158  0.569641  0.416103  0.124362  0.531170  0.001448
# 6245  0.010646  0.016316  0.424900  0.338019  0.086047  0.369319  0.001628
# 6214  0.069449  0.056867  0.498861  0.588510  0.133101  0.344636  0.006102
# 6184  0.082741  0.070002  0.745069  0.690587  0.259495  0.517575  0.009962
# 6212  0.009181  0.022146  0.588703  0.588356  0.137419  0.566895  0.000117
#
# [6789 rows x 4002 columns]

# %%
new_df = df.sort_values(by=['LATNUM', 'LONGNUM'])
new_df.head()
# Out:
#                DHSID  DHSYEAR  DHSCLUST    LATNUM    LONGNUM  Mean_BMI  \
# 2636  GA201200000154   2012.0     154.0 -3.800620  11.113355     25.39
# 2577  GA201200000095   2012.0      95.0 -3.797578  11.173658     19.97
# 2529  GA201200000047   2012.0      47.0 -3.437109  10.659848     23.05
# 2640  GA201200000158   2012.0     158.0 -3.434576  10.656524     25.20
# 2604  GA201200000122   2012.0     122.0 -3.391259  10.676359     28.44
#
#       Median_BMI  Unmet_Need_Rate  Under5_Mortality_Rate  \
# 2636       24.14            33.33                   4.17
# 2577       19.74            44.44                  11.36
# 2529       21.46            19.05                   4.12
# 2640       24.05            29.41                   4.88
# 2604       26.72            27.27                   9.78
#
#       Skilled_Birth_Attendant_Rate  Stunted_Rate  \
# 2636                         61.11          9.09
# 2577                         85.71         16.67
# 2529                         57.89         13.33
# 2640                         75.00          0.00
# 2604                         64.29         30.77
#
#       Fully_Vaccinated_Children_Rate URBAN_RURA country  year  Mean_BMI_bin  \
# 2636                             NaN          R      GA  2012             2
# 2577                             NaN          U      GA  2012             1
# 2529                             NaN          U      GA  2012             1
# 2640                             NaN          U      GA  2012             2
# 2604                             NaN          R      GA  2012             2
#
#       Under5_Mortality_Rate_bin
# 2636                          0
# 2577                          1
# 2529                          0
# 2640                          0
# 2604                          0

# %%
bmi_df = final_df[['DHSID', 'Mean_BMI']].reset_index(index=False)
mosaiks_features = mosaiks_features.reset_index()

# %%
bmi_df = bmi_df.drop(['index'], axis=1)

# %%
mosaiks_features = mosaiks_features.drop(['index'], axis=1)

# %%
mosaiks_features
# Out:
#          Lat     Lon                  .1        .2        .3        .4  \
# 0     -3.805  11.115  0.003567  0.009148  0.001063  0.000616  0.002156
# 1     -3.795  11.175  0.048069  0.240347  0.011166  0.140129  0.097734
# 2     -3.435  10.655  0.236969  0.737643  0.056487  0.465031  0.417166
# 3     -3.325  11.715  0.021291  0.084021  0.005456  0.021787  0.041146
# 4     -3.265  10.685  0.010693  0.023065  0.008814  0.001304  0.011100
# ...      ...     ...       ...       ...       ...       ...       ...
# 6784  20.725  17.095  0.144272  0.535970  0.007348  0.911490  0.289562
# 6785  21.005  18.065  0.085786  0.431654  0.004482  0.781966  0.194547
# 6786  21.205  17.465  0.110492  0.399591  0.017003  0.592871  0.219231
# 6787  21.355  16.985  0.170205  0.631711  0.009856  0.903199  0.364245
# 6788  21.825  17.445  0.121627  0.536978  0.003440  0.856000  0.255904
#
#             .5        .6        .7  ...     .3990     .3991     .3992  \
# 0     0.019884  0.016484  0.048069  ...  0.000833  0.000678  0.028277
# 1     0.193909  0.061233  0.079044  ...  0.045901  0.038110  0.206072
# 2     0.645002  0.190591  0.170996  ...  0.547161  0.168255  0.529643
# 3     0.068473  0.049016  0.050041  ...  0.031601  0.009235  0.063047
# 4     0.051731  0.023326  0.178463  ...  0.016340  0.021286  0.179684
# ...        ...       ...       ...  ...       ...       ...       ...
# 6784  0.116808  0.016587  0.008054  ...  0.045996  0.011583  0.061987
# 6785  0.058194  0.012264  0.005279  ...  0.044903  0.008777  0.024613
# 6786  0.145222  0.017122  0.032927  ...  0.076904  0.014516  0.114672
# 6787  0.212050  0.030203  0.025561  ...  0.092151  0.008557  0.161044
# 6788  0.084938  0.010842  0.004230  ...  0.049305  0.000662  0.024323
#
#          .3993     .3994     .3995     .3996     .3997     .3998     .3999
# 0     0.007653  0.000426  0.009639  0.186551  0.007131  0.005298  0.000561
# 1     0.079954  0.073183  0.258299  0.717489  0.195653  0.185818  0.033173
# 2     0.368575  0.348760  1.373076  2.388049  1.226486  0.936166  0.130382
# 3     0.037590  0.024492  0.145613  0.360640  0.163581  0.063596  0.011379
# 4     0.058314  0.009046  0.041749  0.603708  0.033940  0.016449  0.013595
# ...        ...       ...       ...       ...       ...       ...       ...
# 6784  0.023291  0.049158  0.569641  0.416103  0.124362  0.531170  0.001448
# 6785  0.010646  0.016316  0.424900  0.338019  0.086047  0.369319  0.001628
# 6786  0.069449  0.056867  0.498861  0.588510  0.133101  0.344636  0.006102
# 6787  0.082741  0.070002  0.745069  0.690587  0.259495  0.517575  0.009962
# 6788  0.009181  0.022146  0.588703  0.588356  0.137419  0.566895  0.000117
#
# [6789 rows x 4002 columns]

# %%
bmi_df
# Out:
#                DHSID  Mean_BMI
# 0     GA201200000154     25.39
# 1     GA201200000095     19.97
# 2     GA201200000047     23.05
# 3     GA201200000122     28.44
# 4     GA201200000333     21.08
# ...              ...       ...
# 6784  TD201400000111     23.38
# 6785  TD201400000387     19.18
# 6786  TD201400000508     20.56
# 6787  TD201400000532     20.86
# 6788  TD201400000625     21.77
#
# [6789 rows x 2 columns]

# %%
complete_df = pd.concat([mosaiks_features, bmi_df], axis=1)

# %%
complete_df.head()
# Out:
#      Lat     Lon                  .1        .2        .3        .4        .5  \
# 0 -3.805  11.115  0.003567  0.009148  0.001063  0.000616  0.002156  0.019884
# 1 -3.795  11.175  0.048069  0.240347  0.011166  0.140129  0.097734  0.193909
# 2 -3.435  10.655  0.236969  0.737643  0.056487  0.465031  0.417166  0.645002
# 3 -3.325  11.715  0.021291  0.084021  0.005456  0.021787  0.041146  0.068473
# 4 -3.265  10.685  0.010693  0.023065  0.008814  0.001304  0.011100  0.051731
#
#          .6        .7  ...     .3992     .3993     .3994     .3995     .3996  \
# 0  0.016484  0.048069  ...  0.028277  0.007653  0.000426  0.009639  0.186551
# 1  0.061233  0.079044  ...  0.206072  0.079954  0.073183  0.258299  0.717489
# 2  0.190591  0.170996  ...  0.529643  0.368575  0.348760  1.373076  2.388049
# 3  0.049016  0.050041  ...  0.063047  0.037590  0.024492  0.145613  0.360640
# 4  0.023326  0.178463  ...  0.179684  0.058314  0.009046  0.041749  0.603708
#
#       .3997     .3998     .3999           DHSID  Mean_BMI
# 0  0.007131  0.005298  0.000561  GA201200000154     25.39
# 1  0.195653  0.185818  0.033173  GA201200000095     19.97
# 2  1.226486  0.936166  0.130382  GA201200000047     23.05
# 3  0.163581  0.063596  0.011379  GA201200000122     28.44
# 4  0.033940  0.016449  0.013595  GA201200000333     21.08
#
# [5 rows x 4004 columns]

# %%
complete_df.to_csv('AL_mosaiks.csv')

# %%
complete_df["Mean_BMI_bin"] = np.select(
        [complete_df["Mean_BMI"] <= 19.9, complete_df["Mean_BMI"] <= 24.9, True], 
        [0, 1, 2]
    )
N_CLASSES = complete_df["Mean_BMI_bin"].drop_duplicates().shape[0]

# %%
complete_df
# Out:
#          Lat     Lon                  .1        .2        .3        .4  \
# 0     -3.805  11.115  0.003567  0.009148  0.001063  0.000616  0.002156
# 1     -3.795  11.175  0.048069  0.240347  0.011166  0.140129  0.097734
# 2     -3.435  10.655  0.236969  0.737643  0.056487  0.465031  0.417166
# 3     -3.325  11.715  0.021291  0.084021  0.005456  0.021787  0.041146
# 4     -3.265  10.685  0.010693  0.023065  0.008814  0.001304  0.011100
# ...      ...     ...       ...       ...       ...       ...       ...
# 6784  20.725  17.095  0.144272  0.535970  0.007348  0.911490  0.289562
# 6785  21.005  18.065  0.085786  0.431654  0.004482  0.781966  0.194547
# 6786  21.205  17.465  0.110492  0.399591  0.017003  0.592871  0.219231
# 6787  21.355  16.985  0.170205  0.631711  0.009856  0.903199  0.364245
# 6788  21.825  17.445  0.121627  0.536978  0.003440  0.856000  0.255904
#
#             .5        .6        .7  ...     .3993     .3994     .3995  \
# 0     0.019884  0.016484  0.048069  ...  0.007653  0.000426  0.009639
# 1     0.193909  0.061233  0.079044  ...  0.079954  0.073183  0.258299
# 2     0.645002  0.190591  0.170996  ...  0.368575  0.348760  1.373076
# 3     0.068473  0.049016  0.050041  ...  0.037590  0.024492  0.145613
# 4     0.051731  0.023326  0.178463  ...  0.058314  0.009046  0.041749
# ...        ...       ...       ...  ...       ...       ...       ...
# 6784  0.116808  0.016587  0.008054  ...  0.023291  0.049158  0.569641
# 6785  0.058194  0.012264  0.005279  ...  0.010646  0.016316  0.424900
# 6786  0.145222  0.017122  0.032927  ...  0.069449  0.056867  0.498861
# 6787  0.212050  0.030203  0.025561  ...  0.082741  0.070002  0.745069
# 6788  0.084938  0.010842  0.004230  ...  0.009181  0.022146  0.588703
#
#          .3996     .3997     .3998     .3999           DHSID  Mean_BMI  \
# 0     0.186551  0.007131  0.005298  0.000561  GA201200000154     25.39
# 1     0.717489  0.195653  0.185818  0.033173  GA201200000095     19.97
# 2     2.388049  1.226486  0.936166  0.130382  GA201200000047     23.05
# 3     0.360640  0.163581  0.063596  0.011379  GA201200000122     28.44
# 4     0.603708  0.033940  0.016449  0.013595  GA201200000333     21.08
# ...        ...       ...       ...       ...             ...       ...
# 6784  0.416103  0.124362  0.531170  0.001448  TD201400000111     23.38
# 6785  0.338019  0.086047  0.369319  0.001628  TD201400000387     19.18
# 6786  0.588510  0.133101  0.344636  0.006102  TD201400000508     20.56
# 6787  0.690587  0.259495  0.517575  0.009962  TD201400000532     20.86
# 6788  0.588356  0.137419  0.566895  0.000117  TD201400000625     21.77
#
#       Mean_BMI_bin
# 0                2
# 1                1
# 2                1
# 3                2
# 4                1
# ...            ...
# 6784             1
# 6785             0
# 6786             1
# 6787             1
# 6788             1
#
# [6789 rows x 4005 columns]

# %%
X = complete_df.drop(['Lat', 'Lon'], axis=1)
y = complete_df['Mean_BMI_bin']

# %%
mosaiks_features = pd.concat([X, y], axis=1)

# %%
mosaiks_features["Mean_BMI_bin"] = np.select(
        [mosaiks_features["Mean_BMI"] <= 19.9, mosaiks_features["Mean_BMI"] <= 24.9, True], 
        [0, 1, 2]
    )
N_CLASSES = mosaiks_features["Mean_BMI_bin"].drop_duplicates().shape[0]
# Out:
# <ipython-input-222-d3c483b945df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mosaiks_features["Mean_BMI_bin"] = np.select(

# %%
mosaiks_features.to_csv('west_africa_mosaiks.csv')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-380e01cd14ed> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#
# NameError: name 'X' is not defined

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=4000)
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=4000)

# %%
score = logreg.score(x_test, y_test)
print(score)
# Out:
# 0.657243816254417

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)

# %%
from transformers import ViTFeatureExtractor, ViTForImageClassification
import torch

# %%
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224-in21k')

# %%
import numpy as np

# %%
def tensor_to_image(tensor):
    tensor = tensor*255
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor)>3:
        assert tensor.shape[0] == 1
        tensor = tensor[0]
    return Image.fromarray(tensor)

# %%
import matplotlib.pyplot as plt

# %%
from torchvision import models, transforms
from PIL import Image
image_arr = torch.from_numpy(np.load('drive/MyDrive/bmi/west_africa/TD201400000452.npy'))
image = Image.fromarray(np.uint8(image_arr))
encodings = feature_extractor(images=image, return_tensors="pt")
pixel_values = encodings["pixel_values"]
arr_ = np.squeeze(pixel_values) # you can give axis attribute if you wanna squeeze in specific dimension
plt.imshow(arr_.T)
plt.axis('off')
plt.show()
#tensor_to_image(pixel_values)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image_arr = torch.from_numpy(np.load('drive/MyDrive/bmi/west_africa/TD201400000452.npy'))
image = Image.fromarray(np.uint8(image_arr))
plt.axis('off')
plt.imshow(image)

# %%
import torch 
import torch.nn as nn 
import torch.nn.functional as F

from torch.nn import BCEWithLogitsLoss, CrossEntropyLoss, MSELoss

from transformers import ViTForImageClassification, ViTModel, ViTConfig

# %%
class ViTMosaiksModel(nn.Module):

	def __init__(self, n_classes, mosaiks_dim = 64, mlp_dim = 128):
		
		super().__init__()

		self.n_classes = n_classes
		# applies pooling layer 
		configuration = ViTConfig()
		self.model = ViTModel(configuration).from_pretrained('google/vit-base-patch16-224-in21k')
		
		hidden_dim = 768
		self.mlp = nn.Sequential(
            nn.Linear(hidden_dim + mosaiks_dim, mlp_dim),
            nn.ReLU(),
            nn.Linear(mlp_dim, mlp_dim),
            nn.ReLU(),            
            nn.Linear(mlp_dim, self.n_classes)
        )
	
	def forward(self, X, mosaiks_features):
		device = 'cuda' if torch.cuda.is_available() else 'cpu'
		model_out = self.model(X)['pooler_output']
		mosaiks_features = mosaiks_features.to(device)
		concat_output = torch.cat((model_out, mosaiks_features), dim=1)
		logits = self.mlp(concat_output)

		return logits

# %%
import torch.optim as optim

# %%
models = ViTMosaiksModel(n_classes=5)
checkpoint = torch.load('/content/drive/MyDrive/bmi/ViT_mosiaks_model.pkl/pytorch_model.bin', map_location=device)

# %%
optimizers = optim.SGD(models.parameters(), lr=0.001, momentum=0.9)
torch.save(models.state_dict(), 'model_weights.pth')
models.load_state_dict(torch.load('model_weights.pth'))
# Out:
# <All keys matched successfully>

# %%
model = models.densenet121(pretrained=True)
model.classifier = nn.Linear(model.classifier.in_features, 3)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
